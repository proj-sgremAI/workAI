# %%
import http.client

conn = http.client.HTTPSConnection("bloomberg-market-and-financial-news.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "401bc49886mshcdd280d02c4404bp1262aejsn051190e0fba0",
    'X-RapidAPI-Host': "bloomberg-market-and-financial-news.p.rapidapi.com"
}

conn.request("GET", "/market/auto-complete?query=AAPL", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"quote":[{"securityType":"ETP","symbol":"AAPL","exchange":"London","country":"Ireland","currency":"GBp","resourceType":"Fund","resourceSubtype":"ETP","region":"EMEA","ticker":"aapl:ln","tickerName":"AAPL:LN","template":"Closed-End Fund","tinyName":"LS 1x Apple Tracker ETP","name":"LS 1x Apple Tracker ETP","watchlist":true,"resourceId":"AAPL:LN","id":"AAPL:LN","title":"LS 1x Apple Tracker ETP","card":"security"},{"securityType":"Common Stock","symbol":"AAPL","exchange":"Vienna","country":"United States","currency":"EUR","resourceType":"Company","fundamentalDataCurrency":"USD","resourceSubtype":"Public","region":"EMEA","ticker":"aapl:av","tickerName":"AAPL:AV","template":"Stock","tinyName":"Apple Inc","name":"Apple Inc","watchlist":true,"resourceId":"AAPL:AV","id":"AAPL:AV","title":"Apple Inc","card":"security"},{"securityType":"Canadian DR","symbol":"AAPL","exchange":"NEO-L Lit","country":"United States","currency":"CAD","resourceType":"Company","fundamentalDataCurrency":"USD","resou
# ...

# %%
import requests

url = "https://real-time-financial-news-and-sentiments.p.rapidapi.com/news/rapidapi"

querystring = {"page":"1","limit":"5","ticker":"AAPL"}

headers = {
	"X-RapidAPI-Key": "401bc49886mshcdd280d02c4404bp1262aejsn051190e0fba0",
	"X-RapidAPI-Host": "real-time-financial-news-and-sentiments.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\dssgr\OneDrive\Desktop\workplace\.venv\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...
